# %%
print("hefgfllo")
# Out:
# hefgfllo

# %%
# Calculator demo
from calculator import evaluate

print('2 + 3*4 =', evaluate('2 + 3*4'))
print('2**8 =', evaluate('2**8'))
print('10 / 3 =', evaluate('10/3'))
